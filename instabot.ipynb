# %%
from instabot import Bot
insta = Bot()
# Login to Instagram account    

insta.login(username="newsbot2025", password="Irfan@123")
# bot.upload_photo("news_post.jpg", caption="🚨 Breaking: New AI Tool Released! #technews #breaking")
# Out:
# 2025-06-19 13:33:30,886 - INFO - Instabot version: 0.117.0 Started
# 2025-06-19 13:33:30,886 - INFO - Instabot version: 0.117.0 Started
# 2025-06-19 13:33:30,889 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2025-06-19 13:33:30,889 - INFO - Not yet logged in starting: PRE-LOGIN FLOW!
# 2025-06-19 13:33:34,930 - INFO - Logged-in successfully as 'newsbot2025'!
# 2025-06-19 13:33:34,930 - INFO - Logged-in successfully as 'newsbot2025'!
# 2025-06-19 13:33:34,931 - INFO - LOGIN FLOW! Just logged-in: True
# 2025-06-19 13:33:34,931 - INFO - LOGIN FLOW! Just logged-in: True
# 2025-06-19 13:33:37,103 - ERROR - Error checking for `feedback_required`, response text is not JSON
# 2025-06-19 13:33:37,103 - ERROR - Error checking for `feedback_required`, response text is not JSON
# 2025-06-19 13:33:37,104 - INFO - Full Response: <Response [404]>
# 2025-06-19 13:33:37,104 - INFO - Full Response: <Response [404]>
# 2025-06-19 13:33:37,105 - INFO - Response Text: <!DOCTYPE html>
# ...

# %%
insta.upload_photo("nj.jpg", caption="🚨 Breaking: New AI Tool Released! #technews #breaking")
# Out:
# FOUND: w:735 h:735 r:1.0
# 2025-06-18 22:42:42,677 - INFO - Photo 'nj.jpg' is uploaded.
# {'pk': 3657825140218325066,
#  'id': '3657825140218325066_75455603076',
#  'fbid': 18064624190118067,
#  'device_timestamp': 1750266740005,
#  'caption_is_edited': False,
#  'strong_id__': '3657825140218325066_75455603076',
#  'deleted_reason': 0,
#  'has_shared_to_fb': 0,
#  'has_delayed_metadata': False,
#  'mezql_token': '',
#  'share_count_disabled': False,
#  'should_request_ads': False,
#  'is_reshare_of_text_post_app_media_in_ig': False,
#  'integrity_review_decision': 'pending',
#  'client_cache_key': 'MzY1NzgyNTE0MDIxODMyNTA2Ng==.3',
#  'filter_type': 0,
#  'is_visual_reply_commenter_notice_enabled': True,
#  'like_and_view_counts_disabled': False,
#  'has_privately_liked': False,
#  'sticker_translations_enabled': False,
#  'is_post_live_clips_media': False,
#  'is_quiet_post': False,
#  'subtype_name_for_REST__': 'XDTFeedMedia',
#  'taken_at': 1750266758,
# ...
